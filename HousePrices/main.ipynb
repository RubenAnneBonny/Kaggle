# %% [markdown]
# # House Prices Kaggle
#
# * Data explorer
# * XGBoost Baseline
# * ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv("train.csv")

train, test = train_test_split(df, test_size=0.2, shuffle=True)

train[:10]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1353  1354          50       RL         56.0    14720   Pave   NaN      IR1
# 354    355          50       RL         60.0     8400   Pave   NaN      Reg
# 995    996          50       RL         51.0     4712   Pave   NaN      IR1
# 147    148          60       RL          NaN     9505   Pave   NaN      IR1
# 1394  1395         120       RL         53.0     4045   Pave   NaN      Reg
# 660    661          60       RL          NaN    12384   Pave   NaN      Reg
# 432    433         160       RM         24.0     1920   Pave   NaN      Reg
# 797    798          20       RL         57.0     7677   Pave   NaN      Reg
# 562    563          30       RL         63.0    13907   Pave   NaN      Reg
# 1275  1276          90       RL         95.0    11345   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# ...

# %%
train.sort_values(by="SalePrice")
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 495    496          30  C (all)         60.0     7879   Pave   NaN      Reg
# 916    917          20  C (all)         50.0     9000   Pave   NaN      Reg
# 533    534          20       RL         50.0     5000   Pave   NaN      Reg
# 710    711          30       RL         56.0     4130   Pave   NaN      IR1
# 1337  1338          30       RM        153.0     4118   Pave  Grvl      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 803    804          60       RL        107.0    13891   Pave   NaN      Reg
# 898    899          20       RL        100.0    12919   Pave   NaN      IR1
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
#
# ...

# %%
import matplotlib.pyplot as plt

train["MSSubClass_flag"] = (train.MSSubClass.astype(int) > 100).astype(int)

plt.scatter(train.SalePrice, train.MSSubClass_flag)

# %%
"""
Possible values for train.MSZoning

A	Agriculture
C	Commercial
FV	Floating Village Residential
I	Industrial
RH	Residential High Density
RL	Residential Low Density
RP	Residential Low Density Park 
RM	Residential Medium Density
"""

zoning_map = {
    "A": 1, "C (all)": 2, "FV": 3, "I": 4,
    "RH": 5, "RL": 6, "RP": 7, "RM": 8
}

train["MSZoning"] = train["MSZoning"].map(zoning_map)

print(train.MSZoning.isna().sum())
print(len(train))

plt.scatter(train.SalePrice, train.MSZoning)
# Out:
# 1168
# 1168
